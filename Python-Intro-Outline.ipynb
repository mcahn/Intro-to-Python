# %% [markdown]
# ## Introduction to Programming Using Python -- Outline
#
# - Python-01--Intro+Outline
#   - Introduce myself
#   - Our task
#   - Python topics
#   - Expectations
# - Python-02-Start-Jupyter--Download-Notebooks
#   - Instructions for starting Jupyter
#   - Instructions for downloading the workshop notebooks
# - Python-03--Jupyter
#   - Cells -- markdown and code
#   - **Exercise 03:** Change a string, make a new cell with a print function
# - Python-04--Variables+Strings
#   - Strings
#   - Operators
#   - Variables
#   - **Exercise 04:** Create a new string variable, compare ' and "
#   - Undefined variables
#   - Comments
# - Python-05--For-Loops
#   - Iterate through a string
#   - range
#   - **Exercise 05:** print the numbers 10 through 20
# - Python-06--Read-a-File
#   - Read a file and print it out
#   - **Exercise 06:** modify code to print the type of the line variable
# - Python-07--Integers-and-Arithmetic
#   - Integers
#   - The arithmetic operators
#   - **Exercise 07:** Modify code to count the number of lines in a file.
# - Python-08--Lists-and-Methods
#   - Lists
#   - List methods "append" and "sort"
# -  Python-09--List-indexes
#   - Indexes
#   - Slices
#   - Why Python uses 0-based indexing.
#   - **Exercise 09:** print a slice of the list animals
# - Python-10--String-Split-Method
#   - animals example
#   - **Exercise 10:** split on commas
# - Python-11--List-Append--String-Split
#   - **Exercise 11:** Print the column headings from a file, numbered
# - Python-12--Gotchas
#   - List references
#   - string.strip vs. list.sort
# - Python-13--If-Statements
#   - if, else, elif
#   - **Exercise 13:** Make a unique list of car makes
# - Python-14--Diciontaries
#   - Key/value pairs
#   - Lists vs. dictionaries
#   - Brackets and braces
#   - Keys and values
#   - Iterating over a dictionary
# - Python-15--Dictionaries-Continued
#   - **Exercise 15:** Count the car makes
# - Python-16--Tuples
#   - Immutable
#   - Indexed
#   - Brackets vs. braces vs. parentheses
#   - Tuple with one element
#   - **Exercise 16:** Count how often each make and model is involved in a traffic violations.
# - Python-17--Floats
#   - float type
#   - Inexact representation
# - Python-18--Functions
#   - Celsius to Fahrenheit example
#   - **Exercise 18:** Print a Fahrenheit to Celsius conversion table
# - Python-19--Functions-Continued
#   - **Exercise 19:** Write a function to normalize traffic violations by make, and print the normalized data.
# - Python-20--Whats-Next
#   - Importing modules
#   - Exceptions
